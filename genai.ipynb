# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhitha-utada/GEN-AI/blob/main/genai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAY -01

# %%
print("I am gonna finish this GEN AI COURSE")
# Out:
# I am gonna finish this GEN AI COURSE

# %% [markdown]
# Hey this is the course for GEN AI

# %% [markdown]
# ## Identifiers
# 1.   names of variables, functions, classes
# 2.   cant start with numbers
# 3.   can contain alphabets, numbers, and no special characters

# %% [markdown]
# ## comments
#
#
# 1.   single line - #
# 2.   multi line - """ comment """

# %% [markdown]
# #DAY 02
# ## Indentation:
#
#
# *   To represent a block of code
# *   Usually represented by a tab(4 whitespaces)
#
# ## Variables:
#
#
# *  Name used for storing a value in a memory location
# *  We can assign multiple variables in a single line seperating them using ;
#
# *   We can assign a different value to multiple variables using ,
# *   Same value will be stored under same memory location
#
#
# *   We can find the location of the variable using id()

# %%
if True:
    print("Hey") #spaces before print is indentation
# Out:
# Hey

# %%
age = 18
name = "Nik"; age = 18; city = "pune" #multiple varible assignment in single line
print(name, age, city)
# Out:
# Nik 18 pune

# %%
var1 , var2, var3 = 10, 20, 30 #multiple variable assignment
print(var1, var2, var3)
# Out:
# 10 20 30

# %%
a =10
b = 10
print(id(a)) # as both are same valules python will store them under same location
print(id(b))
# Out:
# 11645640
# 11645640
